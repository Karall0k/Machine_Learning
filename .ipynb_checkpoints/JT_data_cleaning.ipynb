# %% [markdown]
# ### Data Cleaning

# %%
# Import libraries
import pandas as pd

# %%
# Load MLB batting statistics
batter_stats = pd.read_csv('data/batter_stats.csv')

batter_stats.head()
# Out:
#    Rk             Player  HR   AB  Season  Age Team  Lg    G   PA  ...    SLG  \
# 0   1  Giancarlo Stanton  59  597    2017   27  MIA  NL  159  692  ...  0.631
# 1   2        Pete Alonso  53  597    2019   24  NYM  NL  161  693  ...  0.583
# 2   3        Aaron Judge  52  542    2017   25  NYY  AL  155  678  ...  0.627
# 3   4     Eugenio Suárez  49  575    2019   27  CIN  NL  159  662  ...  0.572
# 4   5        Khris Davis  48  576    2018   30  OAK  AL  151  654  ...  0.549
#
#      OPS  OPS+   TB  GIDP  HBP  SH  SF  IBB    Pos
# 0  1.007   169  377    13    7   0   3   13  *9/HD
# 1  0.941   147  348    13   21   0   3    6  *3/HD
# 2  1.049   171  340    15    5   0   4   11  *9D/H
# 3  0.930   131  329    12   11   0   6    4  *5/HD
# 4  0.874   137  316    16   12   0   7    5  *D7/H
#
# [5 rows x 34 columns]

# %%
batter_stats.columns
# Out:
# Index(['Rk', 'Player', 'HR', 'AB', 'Season', 'Age', 'Team', 'Lg', 'G', 'PA',
#        'AB.1', 'R', 'H', '1B', '2B', '3B', 'HR.1', 'RBI', 'SB', 'CS', 'BB',
#        'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB', 'GIDP', 'HBP', 'SH',
#        'SF', 'IBB', 'Pos'],
#       dtype='object')

# %%
# Drop unnecessary columns
batter_stats = batter_stats[['Player', 'Season', 'BA', 'SLG']]

batter_stats.head()
# Out:
#               Player  Season     BA    SLG
# 0  Giancarlo Stanton    2017  0.281  0.631
# 1        Pete Alonso    2019  0.260  0.583
# 2        Aaron Judge    2017  0.284  0.627
# 3     Eugenio Suárez    2019  0.271  0.572
# 4        Khris Davis    2018  0.247  0.549

# %%
# Function to reformat player names
def reorder_name(name):
  name_parts = name.split()
  if len(name_parts) >= 2:
    last_name = name_parts[-1]
    first_name = " ".join(name_parts[:-1])
    return f"{last_name}, {first_name}"
  else:
    return name

# %%
batter_stats['Player'] = batter_stats['Player'].apply(reorder_name)

batter_stats.head()
# Out:
#                Player  Season     BA    SLG
# 0  Stanton, Giancarlo    2017  0.281  0.631
# 1        Alonso, Pete    2019  0.260  0.583
# 2        Judge, Aaron    2017  0.284  0.627
# 3     Suárez, Eugenio    2019  0.271  0.572
# 4        Davis, Khris    2018  0.247  0.549

# %%
# Load StatCast statistics
statcast = pd.read_csv('data/statcast.csv')

statcast
# Out:
#         id  rank  year               player  batted_ball_events  launch_angle  \
# 0        1     1  2022         Judge, Aaron                 341          14.6
# 1        2     2  2022      Alvarez, Yordan                 304          12.1
# 2        3     3  2022          Trout, Mike                 234          24.7
# 3        4     4  2022      Schwarber, Kyle                 312          18.9
# 4        5     5  2022   Stanton, Giancarlo                 228          10.2
# ...    ...   ...   ...                  ...                 ...           ...
# 1978  1979   246  2015         Peña, Brayan                 302           8.0
# 1979  1980   247  2015          Reyes, José                 431          13.3
# 1980  1981   248  2015         Sogard, Eric                 326          11.6
# 1981  1982   249  2015          Revere, Ben                 536           5.1
# 1982  1983   250  2015       Iglesias, José                 379           4.5
#
#       sweet_spot_percentage  max_ev  average_ev  fly_ball_line_drive_ev  \
# 0                      37.8   118.4        95.8                   100.2
# 1                      40.1   117.4        95.5                    98.2
# 2                      37.2   114.4        91.7                    94.9
# 3                      34.6   114.8        93.3                    99.7
# 4                      26.3   119.8        94.6                    98.2
# ...                     ...     ...         ...                     ...
# 1978                   24.8   104.9        85.6                    86.9
# 1979                   28.1   108.4        84.6                    86.0
# 1980                   32.2   107.5        85.5                    86.5
# 1981                   34.9   111.4        83.1                    86.0
# 1982                   26.1   108.6        83.7                    87.0
#
#       ground_ball_ev  max_distance  average_distance  average_homerun  \
# 0               89.1           465               205            413.0
# 1               92.7           469               193            403.0
# 2               87.7           472               218            407.0
# 3               87.2           468               197            415.0
# 4               94.1           445               160            400.0
# ...              ...           ...               ...              ...
# 1978            85.8           378               137              NaN
# 1979            85.9           419               151            386.0
# 1980            85.9           410               155            410.0
# 1981            81.3           389               133            367.0
# 1982            83.1           377               135            366.0
#
#       hard_hit_95mph+  hard_hit_percentage  hard_hit_swing_percentage  \
# 0                 210                 61.6                       20.3
# 1                 186                 61.2                       23.7
# 2                 120                 51.3                       16.5
# 3                 170                 54.5                       17.6
# 4                 117                 51.3                       17.8
# ...               ...                  ...                        ...
# 1978               52                 17.2                        8.9
# 1979               80                 18.6                        8.8
# 1980               61                 18.7                       10.1
# 1981               78                 14.6                        8.2
# 1982               71                 18.7                        9.1
#
#       total_barrels  barrels_batted_balls_percentage  \
# 0                91                             26.7
# 1                59                             19.4
# 2                46                             19.7
# 3                64                             20.5
# 4                42                             18.4
# ...             ...                              ...
# 1978              1                              0.3
# 1979              1                              0.2
# 1980              1                              0.3
# 1981              0                              0.0
# 1982              0                              0.0
#
#       barrels_plate_appearance_percentage
# 0                                    15.8
# 1                                    12.7
# 2                                    11.6
# 3                                    11.5
# 4                                    11.3
# ...                                   ...
# 1978                                  0.3
# 1979                                  0.2
# 1980                                  0.2
# 1981                                  0.0
# 1982                                  0.0
#
# [1983 rows x 20 columns]

# %%
# Drop unnecessary columns
#statcast.drop(['id', 'rank','average_homerun'], axis=1, inplace=True)
statcast.drop(['id'], axis=1, inplace=True)
# Rename columns
statcast.rename(columns={
    'year': 'Season',
    'player': 'Player'
}, inplace=True)

statcast.head()
# Out:
#    rank  Season               Player  batted_ball_events  launch_angle  \
# 0     1    2022         Judge, Aaron                 341          14.6
# 1     2    2022      Alvarez, Yordan                 304          12.1
# 2     3    2022          Trout, Mike                 234          24.7
# 3     4    2022      Schwarber, Kyle                 312          18.9
# 4     5    2022   Stanton, Giancarlo                 228          10.2
#
#    sweet_spot_percentage  max_ev  average_ev  fly_ball_line_drive_ev  \
# 0                   37.8   118.4        95.8                   100.2
# 1                   40.1   117.4        95.5                    98.2
# 2                   37.2   114.4        91.7                    94.9
# 3                   34.6   114.8        93.3                    99.7
# 4                   26.3   119.8        94.6                    98.2
#
#    ground_ball_ev  max_distance  average_distance  average_homerun  \
# 0            89.1           465               205            413.0
# 1            92.7           469               193            403.0
# 2            87.7           472               218            407.0
# 3            87.2           468               197            415.0
# 4            94.1           445               160            400.0
#
#    hard_hit_95mph+  hard_hit_percentage  hard_hit_swing_percentage  \
# 0              210                 61.6                       20.3
# 1              186                 61.2                       23.7
# 2              120                 51.3                       16.5
# 3              170                 54.5                       17.6
# 4              117                 51.3                       17.8
#
#    total_barrels  barrels_batted_balls_percentage  \
# 0             91                             26.7
# 1             59                             19.4
# 2             46                             19.7
# 3             64                             20.5
# 4             42                             18.4
#
#    barrels_plate_appearance_percentage
# 0                                 15.8
# 1                                 12.7
# 2                                 11.6
# 3                                 11.5
# 4                                 11.3

# %%
# Strip whitespace
statcast = statcast.map(lambda x: x.strip() if isinstance(x, str) else x)

statcast.head()
# Out:
#    rank  Season              Player  batted_ball_events  launch_angle  \
# 0     1    2022        Judge, Aaron                 341          14.6
# 1     2    2022     Alvarez, Yordan                 304          12.1
# 2     3    2022         Trout, Mike                 234          24.7
# 3     4    2022     Schwarber, Kyle                 312          18.9
# 4     5    2022  Stanton, Giancarlo                 228          10.2
#
#    sweet_spot_percentage  max_ev  average_ev  fly_ball_line_drive_ev  \
# 0                   37.8   118.4        95.8                   100.2
# 1                   40.1   117.4        95.5                    98.2
# 2                   37.2   114.4        91.7                    94.9
# 3                   34.6   114.8        93.3                    99.7
# 4                   26.3   119.8        94.6                    98.2
#
#    ground_ball_ev  max_distance  average_distance  average_homerun  \
# 0            89.1           465               205            413.0
# 1            92.7           469               193            403.0
# 2            87.7           472               218            407.0
# 3            87.2           468               197            415.0
# 4            94.1           445               160            400.0
#
#    hard_hit_95mph+  hard_hit_percentage  hard_hit_swing_percentage  \
# 0              210                 61.6                       20.3
# 1              186                 61.2                       23.7
# 2              120                 51.3                       16.5
# 3              170                 54.5                       17.6
# 4              117                 51.3                       17.8
#
#    total_barrels  barrels_batted_balls_percentage  \
# 0             91                             26.7
# 1             59                             19.4
# 2             46                             19.7
# 3             64                             20.5
# 4             42                             18.4
#
#    barrels_plate_appearance_percentage
# 0                                 15.8
# 1                                 12.7
# 2                                 11.6
# 3                                 11.5
# 4                                 11.3

# %%
# Merge our DataFrames
batting_df = batter_stats.merge(statcast, how="inner", on=['Player', 'Season'])

batting_df
# Out:
#                   Player  Season     BA    SLG  rank  batted_ball_events  \
# 0     Stanton, Giancarlo    2017  0.281  0.631     3                 437
# 1           Alonso, Pete    2019  0.260  0.583    11                 417
# 2           Judge, Aaron    2017  0.284  0.627     1                 338
# 3        Suárez, Eugenio    2019  0.271  0.572    30                 392
# 4           Davis, Khris    2018  0.247  0.549     2                 408
# ..                   ...     ...    ...    ...   ...                 ...
# 718        Smith, Mallex    2018  0.296  0.406   239                 391
# 719  Strange-Gordon, Dee    2017  0.308  0.375   256                 566
# 720        Wolters, Tony    2019  0.262  0.329   249                 299
# 721      Hamilton, Billy    2019  0.218  0.275   250                 234
# 722    Hernández, Gorkys    2017  0.255  0.326   247                 241
#
#      launch_angle  sweet_spot_percentage  max_ev  average_ev  ...  \
# 0            11.2                   31.6   122.2        92.0  ...
# 1            14.8                   36.9   118.3        90.7  ...
# 2            15.8                   38.2   121.1        95.0  ...
# 3            17.7                   38.0   112.3        89.3  ...
# 4            18.1                   37.7   112.8        92.5  ...
# ..            ...                    ...     ...         ...  ...
# 718           3.7                   32.2   104.7        85.8  ...
# 719           2.2                   27.7   104.1        81.6  ...
# 720          10.1                   37.5   103.4        85.3  ...
# 721          15.2                   32.1    99.9        80.7  ...
# 722           9.3                   31.1   108.9        85.2  ...
#
#      ground_ball_ev  max_distance  average_distance  average_homerun  \
# 0              86.8           468               183            418.0
# 1              85.9           489               189            414.0
# 2              88.6           496               216            413.0
# 3              86.1           457               195            400.0
# 4              87.7           438               211            405.0
# ..              ...           ...               ...              ...
# 718            83.3           412               144            394.0
# 719            79.6           395               122            380.0
# 720            83.1           413               166            361.0
# 721            81.1           374               155              NaN
# 722            84.6           389               150              NaN
#
#      hard_hit_95mph+  hard_hit_percentage  hard_hit_swing_percentage  \
# 0                199                 45.6                       17.0
# 1                176                 42.7                       13.7
# 2                185                 54.7                       15.1
# 3                157                 40.8                       13.0
# 4                195                 48.1                       15.7
# ..               ...                  ...                        ...
# 718               90                 23.0                        8.8
# 719               63                 11.2                        4.8
# 720               59                 19.7                        8.6
# 721               17                  7.3                        2.5
# 722               63                 26.1                        9.3
#
#      total_barrels  barrels_batted_balls_percentage  \
# 0               76                             17.4
# 1               66                             15.8
# 2               87                             25.7
# 3               54                             13.8
# 4               70                             17.2
# ..             ...                              ...
# 718              6                              1.5
# 719              1                              0.2
# 720              0                              0.0
# 721              0                              0.0
# 722              4                              1.7
#
#      barrels_plate_appearance_percentage
# 0                                   11.0
# 1                                    9.5
# 2                                   12.8
# 3                                    8.2
# 4                                   10.7
# ..                                   ...
# 718                                  1.1
# 719                                  0.1
# 720                                  0.0
# 721                                  0.0
# 722                                  1.1
#
# [723 rows x 21 columns]

# %%
# Replace all above-average BAs with 1 and below-average BAs with 0
batting_df.loc[batting_df['BA'] >= batting_df['BA'].quantile(0.5), 'BA'] = 1
batting_df.loc[batting_df['BA'] < batting_df['BA'].quantile(0.5), 'BA'] = 0

# Replace all above-average SLGs with 1 and below-average SLGs with 0
batting_df.loc[batting_df['SLG'] >= batting_df['SLG'].quantile(0.5), 'SLG'] = 1
batting_df.loc[batting_df['SLG'] < batting_df['SLG'].quantile(0.5), 'SLG'] = 0

# Rename columns
batting_df.rename(columns={
    'BA': 'BA > AVG',
    'SLG': 'SLG > AVG'
}, inplace=True)

batting_df.head()
# Out:
#                Player  Season  BA > AVG  SLG > AVG  rank  batted_ball_events  \
# 0  Stanton, Giancarlo    2017       1.0        1.0     3                 437
# 1        Alonso, Pete    2019       0.0        1.0    11                 417
# 2        Judge, Aaron    2017       1.0        1.0     1                 338
# 3     Suárez, Eugenio    2019       1.0        1.0    30                 392
# 4        Davis, Khris    2018       0.0        1.0     2                 408
#
#    launch_angle  sweet_spot_percentage  max_ev  average_ev  ...  \
# 0          11.2                   31.6   122.2        92.0  ...
# 1          14.8                   36.9   118.3        90.7  ...
# 2          15.8                   38.2   121.1        95.0  ...
# 3          17.7                   38.0   112.3        89.3  ...
# 4          18.1                   37.7   112.8        92.5  ...
#
#    ground_ball_ev  max_distance  average_distance  average_homerun  \
# 0            86.8           468               183            418.0
# 1            85.9           489               189            414.0
# 2            88.6           496               216            413.0
# 3            86.1           457               195            400.0
# 4            87.7           438               211            405.0
#
#    hard_hit_95mph+  hard_hit_percentage  hard_hit_swing_percentage  \
# 0              199                 45.6                       17.0
# 1              176                 42.7                       13.7
# 2              185                 54.7                       15.1
# 3              157                 40.8                       13.0
# 4              195                 48.1                       15.7
#
#    total_barrels  barrels_batted_balls_percentage  \
# 0             76                             17.4
# 1             66                             15.8
# 2             87                             25.7
# 3             54                             13.8
# 4             70                             17.2
#
#    barrels_plate_appearance_percentage
# 0                                 11.0
# 1                                  9.5
# 2                                 12.8
# 3                                  8.2
# 4                                 10.7
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Training the Random Forest Model

# %%
# Import libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Define features set
X = batting_df.copy()
X.drop(['Player', 'Season', 'BA > AVG', 'SLG > AVG'], axis=1, inplace=True)
X.head()
# Out:
#    rank  batted_ball_events  launch_angle  sweet_spot_percentage  max_ev  \
# 0     3                 437          11.2                   31.6   122.2
# 1    11                 417          14.8                   36.9   118.3
# 2     1                 338          15.8                   38.2   121.1
# 3    30                 392          17.7                   38.0   112.3
# 4     2                 408          18.1                   37.7   112.8
#
#    average_ev  fly_ball_line_drive_ev  ground_ball_ev  max_distance  \
# 0        92.0                   100.0            86.8           468
# 1        90.7                    96.6            85.9           489
# 2        95.0                   100.5            88.6           496
# 3        89.3                    93.1            86.1           457
# 4        92.5                    97.2            87.7           438
#
#    average_distance  average_homerun  hard_hit_95mph+  hard_hit_percentage  \
# 0               183            418.0              199                 45.6
# 1               189            414.0              176                 42.7
# 2               216            413.0              185                 54.7
# 3               195            400.0              157                 40.8
# 4               211            405.0              195                 48.1
#
#    hard_hit_swing_percentage  total_barrels  barrels_batted_balls_percentage  \
# 0                       17.0             76                             17.4
# 1                       13.7             66                             15.8
# 2                       15.1             87                             25.7
# 3                       13.0             54                             13.8
# 4                       15.7             70                             17.2
#
#    barrels_plate_appearance_percentage
# 0                                 11.0
# 1                                  9.5
# 2                                 12.8
# 3                                  8.2
# 4                                 10.7

# %%
len(X.columns)
# Out:
# 17

# %%
# Define target vector
y = batting_df['SLG > AVG'].ravel()
y[:5]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
# Splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create StandardScaler
scaler = StandardScaler()

# %%
# Fitting standard scaler
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=1000, random_state=1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           75           14
# Actual 1           15           77
# Accuracy Score : 0.8397790055248618
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.84      0.84        89
#          1.0       0.85      0.84      0.84        92
#
#     accuracy                           0.84       181
#    macro avg       0.84      0.84      0.84       181
# weighted avg       0.84      0.84      0.84       181

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.11758874548709672, 'rank'),
#  (0.11699447035974471, 'total_barrels'),
#  (0.08912880922183301, 'barrels_plate_appearance_percentage'),
#  (0.06999120339062348, 'barrels_batted_balls_percentage'),
#  (0.059953860091934624, 'hard_hit_95mph+'),
#  (0.05654346082894745, 'average_distance'),
#  (0.05556702912935529, 'sweet_spot_percentage'),
#  (0.05256897717890877, 'hard_hit_percentage'),
#  (0.050515739434661644, 'launch_angle'),
#  (0.049800245629434164, 'fly_ball_line_drive_ev'),
#  (0.049044906276934, 'batted_ball_events'),
#  (0.04339317803514947, 'max_distance'),
#  (0.04141347483057196, 'hard_hit_swing_percentage'),
#  (0.03829405416259709, 'average_homerun'),
#  (0.03743487335810951, 'max_ev'),
#  (0.037113670173353416, 'average_ev'),
#  (0.03465330241074463, 'ground_ball_ev')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>

# %% [markdown]
# ### Optimization Option #1: Data Transformation

# %%
import numpy as np
import math

# %%
def square_value(value):
    sq_val = value*value
    return sq_val

# %%
def exponential(value):
    exp_val = np.exp(value)
    return exp_val

# %%
def sine(value):
    sin_val = math.sin(value)
    return sin_val

# %%
def cosine(value):
    cos_val = math.cos(value)
    return cos_val

# %%
op_batting_df = batting_df.copy()
op_batting_df
# Out:
#                   Player  Season  BA > AVG  SLG > AVG  rank  \
# 0     Stanton, Giancarlo    2017       1.0        1.0     3
# 1           Alonso, Pete    2019       0.0        1.0    11
# 2           Judge, Aaron    2017       1.0        1.0     1
# 3        Suárez, Eugenio    2019       1.0        1.0    30
# 4           Davis, Khris    2018       0.0        1.0     2
# ..                   ...     ...       ...        ...   ...
# 718        Smith, Mallex    2018       1.0        0.0   239
# 719  Strange-Gordon, Dee    2017       1.0        0.0   256
# 720        Wolters, Tony    2019       1.0        0.0   249
# 721      Hamilton, Billy    2019       0.0        0.0   250
# 722    Hernández, Gorkys    2017       0.0        0.0   247
#
#      batted_ball_events  launch_angle  sweet_spot_percentage  max_ev  \
# 0                   437          11.2                   31.6   122.2
# 1                   417          14.8                   36.9   118.3
# 2                   338          15.8                   38.2   121.1
# 3                   392          17.7                   38.0   112.3
# 4                   408          18.1                   37.7   112.8
# ..                  ...           ...                    ...     ...
# 718                 391           3.7                   32.2   104.7
# 719                 566           2.2                   27.7   104.1
# 720                 299          10.1                   37.5   103.4
# 721                 234          15.2                   32.1    99.9
# 722                 241           9.3                   31.1   108.9
#
#      average_ev  ...  ground_ball_ev  max_distance  average_distance  \
# 0          92.0  ...            86.8           468               183
# 1          90.7  ...            85.9           489               189
# 2          95.0  ...            88.6           496               216
# 3          89.3  ...            86.1           457               195
# 4          92.5  ...            87.7           438               211
# ..          ...  ...             ...           ...               ...
# 718        85.8  ...            83.3           412               144
# 719        81.6  ...            79.6           395               122
# 720        85.3  ...            83.1           413               166
# 721        80.7  ...            81.1           374               155
# 722        85.2  ...            84.6           389               150
#
#      average_homerun  hard_hit_95mph+  hard_hit_percentage  \
# 0              418.0              199                 45.6
# 1              414.0              176                 42.7
# 2              413.0              185                 54.7
# 3              400.0              157                 40.8
# 4              405.0              195                 48.1
# ..               ...              ...                  ...
# 718            394.0               90                 23.0
# 719            380.0               63                 11.2
# 720            361.0               59                 19.7
# 721              NaN               17                  7.3
# 722              NaN               63                 26.1
#
#      hard_hit_swing_percentage  total_barrels  \
# 0                         17.0             76
# 1                         13.7             66
# 2                         15.1             87
# 3                         13.0             54
# 4                         15.7             70
# ..                         ...            ...
# 718                        8.8              6
# 719                        4.8              1
# 720                        8.6              0
# 721                        2.5              0
# 722                        9.3              4
#
#      barrels_batted_balls_percentage  barrels_plate_appearance_percentage
# 0                               17.4                                 11.0
# 1                               15.8                                  9.5
# 2                               25.7                                 12.8
# 3                               13.8                                  8.2
# 4                               17.2                                 10.7
# ..                               ...                                  ...
# 718                              1.5                                  1.1
# 719                              0.2                                  0.1
# 720                              0.0                                  0.0
# 721                              0.0                                  0.0
# 722                              1.7                                  1.1
#
# [723 rows x 21 columns]

# %%
feature_list = list(op_batting_df.columns)
feature_list
# Out:
# ['Player',
#  'Season',
#  'BA > AVG',
#  'SLG > AVG',
#  'rank',
#  'batted_ball_events',
#  'launch_angle',
#  'sweet_spot_percentage',
#  'max_ev',
#  'average_ev',
#  'fly_ball_line_drive_ev',
#  'ground_ball_ev',
#  'max_distance',
#  'average_distance',
#  'average_homerun',
#  'hard_hit_95mph+',
#  'hard_hit_percentage',
#  'hard_hit_swing_percentage',
#  'total_barrels',
#  'barrels_batted_balls_percentage',
#  'barrels_plate_appearance_percentage']

# %%
del(feature_list[0:4])

# %%
feature_list
# Out:
# ['rank',
#  'batted_ball_events',
#  'launch_angle',
#  'sweet_spot_percentage',
#  'max_ev',
#  'average_ev',
#  'fly_ball_line_drive_ev',
#  'ground_ball_ev',
#  'max_distance',
#  'average_distance',
#  'average_homerun',
#  'hard_hit_95mph+',
#  'hard_hit_percentage',
#  'hard_hit_swing_percentage',
#  'total_barrels',
#  'barrels_batted_balls_percentage',
#  'barrels_plate_appearance_percentage']

# %%
for name in feature_list:
    op_batting_df[name + '_squared'] = op_batting_df[name].apply(square_value)

op_batting_df.head()
# Out:
#                Player  Season  BA > AVG  SLG > AVG  rank  batted_ball_events  \
# 0  Stanton, Giancarlo    2017       1.0        1.0     3                 437
# 1        Alonso, Pete    2019       0.0        1.0    11                 417
# 2        Judge, Aaron    2017       1.0        1.0     1                 338
# 3     Suárez, Eugenio    2019       1.0        1.0    30                 392
# 4        Davis, Khris    2018       0.0        1.0     2                 408
#
#    launch_angle  sweet_spot_percentage  max_ev  average_ev  ...  \
# 0          11.2                   31.6   122.2        92.0  ...
# 1          14.8                   36.9   118.3        90.7  ...
# 2          15.8                   38.2   121.1        95.0  ...
# 3          17.7                   38.0   112.3        89.3  ...
# 4          18.1                   37.7   112.8        92.5  ...
#
#    ground_ball_ev_squared  max_distance_squared  average_distance_squared  \
# 0                 7534.24                219024                     33489
# 1                 7378.81                239121                     35721
# 2                 7849.96                246016                     46656
# 3                 7413.21                208849                     38025
# 4                 7691.29                191844                     44521
#
#    average_homerun_squared  hard_hit_95mph+_squared  \
# 0                 174724.0                    39601
# 1                 171396.0                    30976
# 2                 170569.0                    34225
# 3                 160000.0                    24649
# 4                 164025.0                    38025
#
#    hard_hit_percentage_squared  hard_hit_swing_percentage_squared  \
# 0                      2079.36                             289.00
# 1                      1823.29                             187.69
# 2                      2992.09                             228.01
# 3                      1664.64                             169.00
# 4                      2313.61                             246.49
#
#    total_barrels_squared  barrels_batted_balls_percentage_squared  \
# 0                   5776                                   302.76
# 1                   4356                                   249.64
# 2                   7569                                   660.49
# 3                   2916                                   190.44
# 4                   4900                                   295.84
#
#    barrels_plate_appearance_percentage_squared
# 0                                       121.00
# 1                                        90.25
# 2                                       163.84
# 3                                        67.24
# 4                                       114.49
#
# [5 rows x 38 columns]

# %%
for name in feature_list:
    op_batting_df[name + '_sine'] = op_batting_df[name].apply(sine)

op_batting_df.head()
# Out:
#                Player  Season  BA > AVG  SLG > AVG  rank  batted_ball_events  \
# 0  Stanton, Giancarlo    2017       1.0        1.0     3                 437
# 1        Alonso, Pete    2019       0.0        1.0    11                 417
# 2        Judge, Aaron    2017       1.0        1.0     1                 338
# 3     Suárez, Eugenio    2019       1.0        1.0    30                 392
# 4        Davis, Khris    2018       0.0        1.0     2                 408
#
#    launch_angle  sweet_spot_percentage  max_ev  average_ev  ...  \
# 0          11.2                   31.6   122.2        92.0  ...
# 1          14.8                   36.9   118.3        90.7  ...
# 2          15.8                   38.2   121.1        95.0  ...
# 3          17.7                   38.0   112.3        89.3  ...
# 4          18.1                   37.7   112.8        92.5  ...
#
#    ground_ball_ev_sine  max_distance_sine  average_distance_sine  \
# 0            -0.918628           0.097152               0.708680
# 1            -0.880539          -0.885911               0.483318
# 2             0.593504          -0.363143               0.696058
# 3            -0.957151          -0.994830               0.219455
# 4            -0.261518          -0.968372              -0.491048
#
#    average_homerun_sine  hard_hit_95mph+_sine  hard_hit_percentage_sine  \
# 0             -0.167385             -0.881799                  0.998900
# 1             -0.636715              0.070752                 -0.958672
# 2             -0.992876              0.346621                 -0.961642
# 3             -0.850919             -0.079549                  0.040693
# 4              0.262346              0.219455                 -0.828324
#
#    hard_hit_swing_percentage_sine  total_barrels_sine  \
# 0                       -0.961397            0.566108
# 1                        0.905955           -0.026551
# 2                        0.571197           -0.821818
# 3                        0.420167           -0.558789
# 4                        0.007963            0.773891
#
#    barrels_batted_balls_percentage_sine  \
# 0                             -0.992659
# 1                             -0.091907
# 2                              0.537322
# 3                              0.943696
# 4                             -0.996900
#
#    barrels_plate_appearance_percentage_sine
# 0                                 -0.999990
# 1                                 -0.075151
# 2                                  0.231510
# 3                                  0.940731
# 4                                 -0.956635
#
# [5 rows x 55 columns]

# %%
for name in feature_list:
    op_batting_df[name + '_cosine'] = op_batting_df[name].apply(cosine)

op_batting_df.head()
# Out:
#                Player  Season  BA > AVG  SLG > AVG  rank  batted_ball_events  \
# 0  Stanton, Giancarlo    2017       1.0        1.0     3                 437
# 1        Alonso, Pete    2019       0.0        1.0    11                 417
# 2        Judge, Aaron    2017       1.0        1.0     1                 338
# 3     Suárez, Eugenio    2019       1.0        1.0    30                 392
# 4        Davis, Khris    2018       0.0        1.0     2                 408
#
#    launch_angle  sweet_spot_percentage  max_ev  average_ev  ...  \
# 0          11.2                   31.6   122.2        92.0  ...
# 1          14.8                   36.9   118.3        90.7  ...
# 2          15.8                   38.2   121.1        95.0  ...
# 3          17.7                   38.0   112.3        89.3  ...
# 4          18.1                   37.7   112.8        92.5  ...
#
#    ground_ball_ev_cosine  max_distance_cosine  average_distance_cosine  \
# 0               0.395123            -0.995270                 0.705530
# 1              -0.473974             0.463856                 0.875445
# 2               0.804831             0.931733                -0.717985
# 3              -0.289590            -0.101556                 0.975623
# 4               0.965199            -0.249511                -0.871133
#
#    average_homerun_cosine  hard_hit_95mph+_cosine  hard_hit_percentage_cosine  \
# 0               -0.985892               -0.471626                   -0.046889
# 1                0.771099                0.997494                    0.284514
# 2               -0.119150               -0.938005                   -0.274309
# 3               -0.525296                0.996831                   -0.999172
# 4               -0.964974                0.975623                   -0.560249
#
#    hard_hit_swing_percentage_cosine  total_barrels_cosine  \
# 0                         -0.275163              0.824331
# 1                          0.423375             -0.999647
# 2                         -0.820813              0.569750
# 3                          0.907447             -0.829310
# 4                         -0.999968              0.633319
#
#    barrels_batted_balls_percentage_cosine  \
# 0                                0.120944
# 1                               -0.995768
# 2                                0.843377
# 3                                0.330815
# 4                               -0.078678
#
#    barrels_plate_appearance_percentage_cosine
# 0                                    0.004426
# 1                                   -0.997172
# 2                                    0.972833
# 3                                   -0.339155
# 4                                   -0.291289
#
# [5 rows x 72 columns]

# %%
for name in feature_list:
    op_batting_df[name + '_exp'] = op_batting_df[name].apply(exponential)

op_batting_df.head()
# Out:
#                Player  Season  BA > AVG  SLG > AVG  rank  batted_ball_events  \
# 0  Stanton, Giancarlo    2017       1.0        1.0     3                 437
# 1        Alonso, Pete    2019       0.0        1.0    11                 417
# 2        Judge, Aaron    2017       1.0        1.0     1                 338
# 3     Suárez, Eugenio    2019       1.0        1.0    30                 392
# 4        Davis, Khris    2018       0.0        1.0     2                 408
#
#    launch_angle  sweet_spot_percentage  max_ev  average_ev  ...  \
# 0          11.2                   31.6   122.2        92.0  ...
# 1          14.8                   36.9   118.3        90.7  ...
# 2          15.8                   38.2   121.1        95.0  ...
# 3          17.7                   38.0   112.3        89.3  ...
# 4          18.1                   37.7   112.8        92.5  ...
#
#    ground_ball_ev_exp  max_distance_exp  average_distance_exp  \
# 0        4.974633e+37     1.777532e+203          2.991508e+79
# 1        2.022535e+37     2.344238e+212          1.206861e+82
# 2        3.009477e+38     2.570769e+215          6.421080e+93
# 3        2.470330e+37     2.968781e+198          4.868823e+84
# 4        1.223562e+38     1.663348e+190          4.326490e+91
#
#    average_homerun_exp  hard_hit_95mph+_exp  hard_hit_percentage_exp  \
# 0        3.428415e+181         2.658287e+86             6.365439e+19
# 1        6.279362e+179         2.727902e+76             3.502470e+18
# 2        2.310048e+179         2.210442e+80             5.700437e+23
# 3        5.221470e+173         1.528388e+68             5.238595e+17
# 4        7.749348e+175         4.868823e+84             7.754692e+20
#
#    hard_hit_swing_percentage_exp  total_barrels_exp  \
# 0                   2.415495e+07       1.014800e+33
# 1                   8.909112e+05       4.607187e+28
# 2                   3.612823e+06       6.076030e+37
# 3                   4.424134e+05       2.830753e+23
# 4                   6.582993e+06       2.515439e+30
#
#    barrels_batted_balls_percentage_exp  \
# 0                         3.603496e+07
# 1                         7.275332e+06
# 2                         1.450001e+11
# 3                         9.846091e+05
# 4                         2.950293e+07
#
#    barrels_plate_appearance_percentage_exp
# 0                             59874.141715
# 1                             13359.726830
# 2                            362217.449611
# 3                              3640.950307
# 4                             44355.855130
#
# [5 rows x 89 columns]

# %% [markdown]
# ### No Transformation

# %%
#op_batting_df = batting_df.copy()
#op_batting_df.head()

# %% [markdown]
# ### X squared tester

# %%
#op_batting_df = batting_df.copy()
#op_batting_df['total_barrels_squared'] = op_batting_df['total_barrels'].apply(square_value)
#op_batting_df.head()

# %% [markdown]
# ### Exponential Tester

# %%
#op_batting_df = batting_df.copy()
#op_batting_df['total_barrels_exp'] = op_batting_df['total_barrels'].apply(exponential)
#op_batting_df.head()

# %% [markdown]
# ### Sine Tester

# %%
#op_batting_df = batting_df.copy()
#op_batting_df['launch_angle_sine'] = op_batting_df['launch_angle'].apply(sine)
#op_batting_df.head()

# %% [markdown]
# ### Cosine Tester

# %%
#op_batting_df = batting_df.copy()
#op_batting_df['launch_angle_cosine'] = op_batting_df['launch_angle'].apply(cosine)
#op_batting_df.head()

# %%
# Define features set
X = op_batting_df.copy()
X.drop(['Player', 'Season', 'BA > AVG', 'SLG > AVG'], axis=1, inplace=True)
X.head()
# Out:
#    rank  batted_ball_events  launch_angle  sweet_spot_percentage  max_ev  \
# 0     3                 437          11.2                   31.6   122.2
# 1    11                 417          14.8                   36.9   118.3
# 2     1                 338          15.8                   38.2   121.1
# 3    30                 392          17.7                   38.0   112.3
# 4     2                 408          18.1                   37.7   112.8
#
#    average_ev  fly_ball_line_drive_ev  ground_ball_ev  max_distance  \
# 0        92.0                   100.0            86.8           468
# 1        90.7                    96.6            85.9           489
# 2        95.0                   100.5            88.6           496
# 3        89.3                    93.1            86.1           457
# 4        92.5                    97.2            87.7           438
#
#    average_distance  ...  ground_ball_ev_exp  max_distance_exp  \
# 0               183  ...        4.974633e+37     1.777532e+203
# 1               189  ...        2.022535e+37     2.344238e+212
# 2               216  ...        3.009477e+38     2.570769e+215
# 3               195  ...        2.470330e+37     2.968781e+198
# 4               211  ...        1.223562e+38     1.663348e+190
#
#    average_distance_exp  average_homerun_exp  hard_hit_95mph+_exp  \
# 0          2.991508e+79        3.428415e+181         2.658287e+86
# 1          1.206861e+82        6.279362e+179         2.727902e+76
# 2          6.421080e+93        2.310048e+179         2.210442e+80
# 3          4.868823e+84        5.221470e+173         1.528388e+68
# 4          4.326490e+91        7.749348e+175         4.868823e+84
#
#    hard_hit_percentage_exp  hard_hit_swing_percentage_exp  total_barrels_exp  \
# 0             6.365439e+19                   2.415495e+07       1.014800e+33
# 1             3.502470e+18                   8.909112e+05       4.607187e+28
# 2             5.700437e+23                   3.612823e+06       6.076030e+37
# 3             5.238595e+17                   4.424134e+05       2.830753e+23
# 4             7.754692e+20                   6.582993e+06       2.515439e+30
#
#    barrels_batted_balls_percentage_exp  \
# 0                         3.603496e+07
# 1                         7.275332e+06
# 2                         1.450001e+11
# 3                         9.846091e+05
# 4                         2.950293e+07
#
#    barrels_plate_appearance_percentage_exp
# 0                             59874.141715
# 1                             13359.726830
# 2                            362217.449611
# 3                              3640.950307
# 4                             44355.855130
#
# [5 rows x 85 columns]

# %%
X.shape
# Out:
# (723, 85)

# %%
# Define target vector
y = op_batting_df['SLG > AVG'].ravel()
y[:5]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
# Splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create StandardScaler
scaler = StandardScaler()

# %%
# Fitting standard scaler
X_scaler = scaler.fit(X_train)
# Out:
# /Users/joshuaturk/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/utils/extmath.py:1156: RuntimeWarning: overflow encountered in square
#   temp **= 2
# /Users/joshuaturk/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/utils/extmath.py:1162: RuntimeWarning: overflow encountered in square
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /Users/joshuaturk/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/utils/extmath.py:1162: RuntimeWarning: invalid value encountered in subtract
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /Users/joshuaturk/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:84: RuntimeWarning: overflow encountered in square
#   upper_bound = n_samples * eps * var + (n_samples * mean * eps) ** 2

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(max_depth=500, n_estimators=1000, max_features=3, random_state=1)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           76           13
# Actual 1           14           78
# Accuracy Score : 0.850828729281768
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.85      0.85        89
#          1.0       0.86      0.85      0.85        92
#
#     accuracy                           0.85       181
#    macro avg       0.85      0.85      0.85       181
# weighted avg       0.85      0.85      0.85       181
